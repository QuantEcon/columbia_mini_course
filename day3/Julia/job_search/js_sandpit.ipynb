# %%
using PyPlot
using LaTeXStrings
plt = PyPlot
# Out:
# PyPlot

# %%
include("JobSearch.jl")
include("lininterp.jl")
# Out:
# interp1d_vectorized (generic function with 1 method)

# %%
self.mc_size = 1000
# Out:
# 1000

# %%
self.mc_size
# Out:
# 1000

# %%
compute_fixed_point(self)
# Out:
# Error at iteration25 is 0.6871167291998859
# Error at iteration50 is 0.162575893344453
# Error at iteration75 is 0.048256545099960135
# Error at iteration100 is 0.015119972426901995
# Error at iteration125 is 0.0048040815534591275
# Error at iteration150 is 0.001533268981972924
# Error at iteration175 is 0.0004900786405102053
# Error at iteration200 is 0.00015673311082764485
#
# Converged in 210 iterations.
# 200-element Array{Float64,1}:
#  103.304
#  103.309
#  103.314
#  103.319
#  103.324
#  103.329
#  103.334
#  103.339
#  103.344
#  103.349
#  103.354
#  103.359
#  103.364
#    ⋮
#  108.487
#  108.655
#  108.834
#  109.024
#  109.226
#  109.44
#  109.668
#  109.911
#  110.17
#  110.449
#  110.75
#  111.074

# %%
res_wage_function = exp.(self.f_star * (1 - self.β))

fig, ax = plt.subplots(figsize=(9, 6))
ax[:plot](self.z_grid, res_wage_function, label="reservation wage given z")
ax[:set](xlabel="z", ylabel="wage")
ax[:legend]()
plt.show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fa0651d8630>)

# %%
self.c
# Out:
# 5

# %%
self.c = 8
# Out:
# 8

# %%
res_wage_function = exp.(self.f_star * (1 - self.β))

fig, ax = plt.subplots(figsize=(9, 6))
ax[:plot](self.z_grid, res_wage_function, label="reservation wage given z")
ax[:set](xlabel="z", ylabel="wage")
ax[:legend]()
plt.show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fa056b754e0>)
