# %%
using PyPlot
using LaTeXStrings
plt = PyPlot
# Out:
# PyPlot

# %%
include("JobSearch.jl")
include("lininterp.jl")
# Out:
# interp1d_vectorized (generic function with 1 method)

# %%
self.mc_size = 1000
# Out:
# 1000

# %%
self.mc_size
# Out:
# 1000

# %%
@time compute_fixed_point(self)
# Out:
# Error at iteration25 is 0.6569857417452738
# Error at iteration50 is 0.14262297542231295
# Error at iteration75 is 0.0389082481380143
# Error at iteration100 is 0.011107275901082403
# Error at iteration125 is 0.0032176966292496445
# Error at iteration150 is 0.0009374348915827113
# Error at iteration175 is 0.0002735325506932895
#
# Converged in 196 iterations.569.012583 seconds (2.92 G allocations: 58.129 GiB, 1.36% gc time)
# 200-element Array{Float64,1}:
#  102.144
#  102.149
#  102.154
#  102.16
#  102.165
#  102.171
#  102.176
#  102.182
#  102.188
#  102.193
#  102.199
#  102.205
#  102.211
#    ⋮
#  108.029
#  108.217
#  108.415
#  108.625
#  108.847
#  109.081
#  109.327
#  109.59
#  109.87
#  110.168
#  110.488
#  110.831

# %%
res_wage_function = exp.(self.f_star * (1 - self.β))

fig, ax = plt.subplots(figsize=(9, 6))
ax[:plot](self.z_grid, res_wage_function, label="reservation wage given z")
ax[:set](xlabel="z", ylabel="wage")
ax[:legend]()
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 900x600 with 1 Axes>)

# %%
self.c
# Out:
# 5

# %%
self.c = 8
# Out:
# 8

# %%
compute_fixed_point(self)
# Out:
# Error at iteration25 is 0.8256170456980527
# Error at iteration50 is 0.23162262710145853
# Error at iteration75 is 0.08413471302010578
# Error at iteration100 is 0.03281585050228841
# Error at iteration125 is 0.013170007986275323
# Error at iteration150 is 0.00534948081322284
# Error at iteration175 is 0.0021802712402916313
# Error at iteration200 is 0.0008892840142493696
# Error at iteration225 is 0.0003627892834430213
# Error at iteration250 is 0.00014800603354103714
#
# Converged in 261 iterations.
# 200-element Array{Float64,1}:
#  113.903
#  113.905
#  113.908
#  113.911
#  113.914
#  113.916
#  113.919
#  113.922
#  113.925
#  113.928
#  113.931
#  113.934
#  113.937
#    ⋮
#  116.638
#  116.715
#  116.796
#  116.881
#  116.97
#  117.064
#  117.162
#  117.266
#  117.376
#  117.495
#  117.621
#  117.756

# %%
res_wage_function = exp.(self.f_star * (1 - self.β))

fig, ax = plt.subplots(figsize=(9, 6))
ax[:plot](self.z_grid, res_wage_function, label="reservation wage given z")
ax[:set](xlabel="z", ylabel="wage")
ax[:legend]()
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 900x600 with 1 Axes>)

# %% [markdown]
# # Multi threads :

# %%
Threads.nthreads()
# Out:
# 4

# %%
include("JobSearch_multithrad.jl")
# Out:
# Q_multithread (generic function with 1 method)

# %%
self.c = 5
# Out:
# 5

# %%
@time compute_fixed_point_multithread(self)
# Out:
# Error at iteration25 is 0.6569857417452738
# Error at iteration50 is 0.14262297542231295
# Error at iteration75 is 0.0389082481380143
# Error at iteration100 is 0.011107275901082403
# Error at iteration125 is 0.0032176966292496445
# Error at iteration150 is 0.0009374348915827113
# Error at iteration175 is 0.0002735325506932895
#
# Converged in 196 iterations.267.323814 seconds (2.51 G allocations: 49.031 GiB, 11.14% gc time)
# 200-element Array{Float64,1}:
#  102.144
#  102.149
#  102.154
#  102.16
#  102.165
#  102.171
#  102.176
#  102.182
#  102.188
#  102.193
#  102.199
#  102.205
#  102.211
#    ⋮
#  108.029
#  108.217
#  108.415
#  108.625
#  108.847
#  109.081
#  109.327
#  109.59
#  109.87
#  110.168
#  110.488
#  110.831

# %%
res_wage_function = exp.(self.f_star * (1 - self.β))

fig, ax = plt.subplots(figsize=(9, 6))
ax[:plot](self.z_grid, res_wage_function, label="reservation wage given z")
ax[:set](xlabel="z", ylabel="wage")
ax[:legend]()
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 900x600 with 1 Axes>)

# %%
self.c
# Out:
# 5

# %%
self.c = 8
# Out:
# 8

# %%
compute_fixed_point_multithread(self)
# Out:
# Error at iteration25 is 0.8256170456980527
# Error at iteration50 is 0.23162262710145853
# Error at iteration75 is 0.08413471302010578
# Error at iteration100 is 0.03281585050228841
# Error at iteration125 is 0.013170007986275323
# Error at iteration150 is 0.00534948081322284
# Error at iteration175 is 0.0021802712402916313
# Error at iteration200 is 0.0008892840142493696
# Error at iteration225 is 0.0003627892834430213
# Error at iteration250 is 0.00014800603354103714
#
# Converged in 261 iterations.
# 200-element Array{Float64,1}:
#  113.903
#  113.905
#  113.908
#  113.911
#  113.914
#  113.916
#  113.919
#  113.922
#  113.925
#  113.928
#  113.931
#  113.934
#  113.937
#    ⋮
#  116.638
#  116.715
#  116.796
#  116.881
#  116.97
#  117.064
#  117.162
#  117.266
#  117.376
#  117.495
#  117.621
#  117.756

# %%
res_wage_function = exp.(self.f_star * (1 - self.β))

fig, ax = plt.subplots(figsize=(9, 6))
ax[:plot](self.z_grid, res_wage_function, label="reservation wage given z")
ax[:set](xlabel="z", ylabel="wage")
ax[:legend]()
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 900x600 with 1 Axes>)
