# %%
using PyPlot
using LaTeXStrings
plt = PyPlot
# Out:
# PyPlot

# %%
include("JobSearch.jl")
include("lininterp.jl")
# Out:
# interp1d_vectorized (generic function with 1 method)

# %%
self.mc_size = 1000
# Out:
# 1000

# %%
self.mc_size
# Out:
# 1000

# %%
@time compute_fixed_point(self)
# Out:
# Error at iteration25 is 0.649588503702148
# Error at iteration50 is 0.13983454163573583
# Error at iteration75 is 0.038013444697611476
# Error at iteration100 is 0.010968913258309954
# Error at iteration125 is 0.0032278175770557027
# Error at iteration150 is 0.0009557887344726623
# Error at iteration175 is 0.00028362059427422537
#
# Converged in 197 iterations.588.771092 seconds (2.94 G allocations: 58.426 GiB, 1.40% gc time)
# 200-element Array{Float64,1}:
#  100.729
#  100.735
#  100.74
#  100.746
#  100.752
#  100.758
#  100.763
#  100.769
#  100.775
#  100.781
#  100.788
#  100.794
#  100.8
#    ⋮
#  107.003
#  107.199
#  107.406
#  107.627
#  107.863
#  108.114
#  108.379
#  108.662
#  108.965
#  109.291
#  109.642
#  110.019

# %%
res_wage_function = exp.(self.f_star * (1 - self.β))

fig, ax = plt.subplots(figsize=(9, 6))
ax[:plot](self.z_grid, res_wage_function, label="reservation wage given z")
ax[:set](xlabel="z", ylabel="wage")
ax[:legend]()
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 900x600 with 1 Axes>)

# %%
self.c
# Out:
# 5

# %%
self.c = 8
# Out:
# 8

# %%
res_wage_function = exp.(self.f_star * (1 - self.β))

fig, ax = plt.subplots(figsize=(9, 6))
ax[:plot](self.z_grid, res_wage_function, label="reservation wage given z")
ax[:set](xlabel="z", ylabel="wage")
ax[:legend]()
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 900x600 with 1 Axes>)

# %% [markdown]
# # Multi threads :

# %%
Threads.nthreads()
# Out:
# 4

# %%
include("JobSearch_multithrad.jl")
# Out:
# Q_multithread (generic function with 1 method)

# %%
self.c = 5
# Out:
# 5

# %%
@time compute_fixed_point_multithread(self)
# Out:
# Error at iteration25 is 0.649588503702148
# Error at iteration50 is 0.13983454163573583
# Error at iteration75 is 0.038013444697611476
# Error at iteration100 is 0.010968913258309954
# Error at iteration125 is 0.0032278175770557027
# Error at iteration150 is 0.0009557887344726623
# Error at iteration175 is 0.00028362059427422537
#
# Converged in 197 iterations.264.027977 seconds (2.46 G allocations: 48.002 GiB, 11.53% gc time)
# 200-element Array{Float64,1}:
#  100.729
#  100.735
#  100.74
#  100.746
#  100.752
#  100.758
#  100.763
#  100.769
#  100.775
#  100.781
#  100.788
#  100.794
#  100.8
#    ⋮
#  107.003
#  107.199
#  107.406
#  107.627
#  107.863
#  108.114
#  108.379
#  108.662
#  108.965
#  109.291
#  109.642
#  110.019

# %%
res_wage_function = exp.(self.f_star * (1 - self.β))

fig, ax = plt.subplots(figsize=(9, 6))
ax[:plot](self.z_grid, res_wage_function, label="reservation wage given z")
ax[:set](xlabel="z", ylabel="wage")
ax[:legend]()
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 900x600 with 1 Axes>)

# %%
self.c
# Out:
# 5

# %%
self.c = 8
# Out:
# 8

# %%
res_wage_function = exp.(self.f_star * (1 - self.β))

fig, ax = plt.subplots(figsize=(9, 6))
ax[:plot](self.z_grid, res_wage_function, label="reservation wage given z")
ax[:set](xlabel="z", ylabel="wage")
ax[:legend]()
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 900x600 with 1 Axes>)
