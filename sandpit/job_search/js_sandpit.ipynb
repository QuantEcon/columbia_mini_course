# %% [markdown]
# ## Job Search
#
# #### John Stachurski

# %% [markdown]
# A McCall job search model with correlated state process, using Jovanovic-style continuation value function iteration, linear interpolation and Monte Carlo integration.

# %%
import numpy as np
import matplotlib.pyplot as plt
from quantecon import tic, toc

# %%
from jobsearch import JobSearch

# %%
js = JobSearch(mc_size=1000)

# %%
js.mc_size
# Out:
# 1000

# %%
tic()
js.compute_fixed_point(verbose=True)
toc()
# Out:
# Error at iteration 25 is 0.6982966152531134.
# Error at iteration 50 is 0.1574308448404338.
# Error at iteration 75 is 0.04462044641563523.
# Error at iteration 100 is 0.013493893565666326.
# Error at iteration 125 is 0.004152025582854435.
# Error at iteration 150 is 0.0012859904213087248.
# Error at iteration 175 is 0.0003993993688027331.
# Error at iteration 200 is 0.00012409436703819665.
#
# Converged in 205 iterations.
# TOC: Elapsed: 0:00:6.91
# 6.910860538482666

# %%
res_wage_function = np.exp(js.f_star * (1 - js.β))

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(js.z_grid, res_wage_function, label="reservation wage given $z$")
ax.set(xlabel="$z$", ylabel="wage")
ax.legend()
plt.show()

# %% [markdown]
# ### Let's try higher unemployment compensation

# %%
js.c
# Out:
# 5

# %%
js.c = 8

# %%
js.compute_fixed_point()
# Out:
# Error at iteration 25 is 0.8766949654781229.
# Error at iteration 50 is 0.24734731595361836.
# Error at iteration 75 is 0.08960163466612414.
# Error at iteration 100 is 0.03475087256364873.
# Error at iteration 125 is 0.013673306703040566.
# Error at iteration 150 is 0.005419675944509095.
# Error at iteration 175 is 0.002159378944796231.
# Error at iteration 200 is 0.0008630258175656991.
# Error at iteration 225 is 0.00034533453079177434.
# Error at iteration 250 is 0.0001383460750332688.
#
# Converged in 259 iterations.

# %%
res_wage_function = np.exp(js.f_star * (1 - js.β))

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(js.z_grid, res_wage_function, label="reservation wage given $z$")
ax.set(xlabel="$z$", ylabel="wage")
ax.legend()
plt.show()
